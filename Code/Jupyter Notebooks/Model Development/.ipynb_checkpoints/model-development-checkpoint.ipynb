# %% [markdown]
# # Model Development Notebook

# %% [markdown]
# This notebook will start my exploration for the optimal model.

# %% [markdown]
# For model development, I will start off my implementing simplier models; then, I will dive into ensemble learning.

# %% [markdown]
# #### Basic Setup

# %%
# Setting up path search
import sys
sys.path.insert(1,'/Users/jinalshah/Jinal/Github Repos/House-Prices-Challenge-Solution/Code/Scripts' + 
               '/Data Preparation Scripts')

# %% [markdown]
# Essentially, in the above code, I utilized the sys module, which helps python navigate through the file system & what not. I have basically told python to look for custom python files in other directories as well.

# %%
# Disabling warnings -> this is not recommended, but I want to see the errors clearly
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Preparing the Data

# %%
# Importing modules & libraries
import pandas as pd
from DataPrepPipeline import Preparation
from sklearn.model_selection import train_test_split

# %%
# Getting the Raw Data 
raw_data = pd.read_csv('/Users/jinalshah/Jinal/Github Repos/House-Prices-Challenge-Solution/Data/train.csv')
raw_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal     208500
# 1         5   2007        WD         Normal     181500
# 2         9   2008        WD         Normal     223500
# 3         2   2006        WD        Abnorml     140000
# 4        12   2008        WD         Normal     250000
# ...     ...    ...       ...            ...        ...
# 1455      8   2007        WD         Normal     175000
# 1456      2   2010        WD         Normal     210000
# 1457      5   2010        WD         Normal     266500
# 1458      4   2010        WD         Normal     142125
# 1459      6   2008        WD         Normal     147500
#
# [1460 rows x 81 columns]

# %%
# Splitting Data into X & y
y = raw_data['SalePrice']
X = raw_data.drop('SalePrice',axis=1)

# %%
# Splitting data into training & testing
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, shuffle=0, random_state=0)

# %%
# Putting the training data through the pipeline
prepare = Preparation(X_train,y_train,True)
train_prepared = prepare.transform()

# %%
train_prepared
# Out:
# array([[20, 'RL', 4.499809670330265, ..., -0.7425753601723825,
#         1.9086720003879953, 0.8888953527775304],
#        [20, 'RL', 4.0943445622221, ..., -0.7425753601723825,
#         -0.5667164585982347, -0.41920248280457134],
#        [30, 'RL', 4.382026634673881, ..., -0.7425753601723825,
#         -0.5667164585982347, 0.4528627409168299],
#        ...,
#        [90, 'RM', 4.219507705176107, ..., -0.7425753601723825,
#         -0.5667164585982347, -0.07037639331601087],
#        [120, 'RL', 4.23410650459726, ..., 0.3811304669013126,
#         -0.4681390420899335, nan],
#        [60, 'RL', 4.060443010546419, ..., -0.7425753601723825,
#         -0.4024207644177327, -0.5064090051767115]], dtype=object)
